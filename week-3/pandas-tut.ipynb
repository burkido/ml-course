# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h1 align="center">Machine Learning in Python</h1>
#     <h3 align="center">Session 01: Pandas</h3>
# </div>

# %% [markdown]
# # Machine Learning

# %% [markdown]
# <img src="https://miro.medium.com/max/601/1*cxfqR8NAj8HGal8CVOZ7hg.png">

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.5.0'

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">pd.read_csv()</span></strong>
# <p dir="rtl" style="text-align: center;"><strong><span style="font-family: courier new, courier;"><span style="font-size: 18pt;">read csv file pandas</span><br /></span></strong></p>
# </div>

# %%
# titanic_data = pd.read_csv(r"C:\Users\soso\Desktop\titanic.csv")
#RAW
# Control+/
titanic_data = pd.read_csv("/home/Machine Learning/week-3/dataset/Data.csv")

# %%
type(titanic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic_data.columns
# titanic_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">head()</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">   Disply first 5  </span></strong></p>
# </div>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em>در صورت ثبت عدد به عنوان پارامتر ورودی، همان تعداد داده از index های ابتدایی دیتافریم را نمایش خواهد داد.</em></span></strong></p>

# %%
type(titanic_data)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#last 5
titanic_data.tail()
# Out:
#       pclass  survived                       name     sex   age  sibsp  parch  \
# 1304       3         0       Zabour, Miss. Hileni  female  14.5      1      0
# 1305       3         0      Zabour, Miss. Thamine  female   NaN      1      0
# 1306       3         0  Zakarian, Mr. Mapriededer    male  26.5      0      0
# 1307       3         0        Zakarian, Mr. Ortin    male  27.0      0      0
# 1308       3         0         Zimmerman, Mr. Leo    male  29.0      0      0
#
#       ticket     fare cabin embarked boat   body home.dest
# 1304    2665  14.4542   NaN        C  NaN  328.0       NaN
# 1305    2665  14.4542   NaN        C  NaN    NaN       NaN
# 1306    2656   7.2250   NaN        C  NaN  304.0       NaN
# 1307    2670   7.2250   NaN        C  NaN    NaN       NaN
# 1308  315082   7.8750   NaN        S  NaN    NaN       NaN

# %%
#random
titanic_data.sample(3)
# Out:
#      pclass  survived                          name     sex   age  sibsp  \
# 591       2         1  West, Miss. Constance Mirium  female   5.0      1
# 518       2         0  Nicholls, Mr. Joseph Charles    male  19.0      1
# 682       3         0            Bourke, Miss. Mary  female   NaN      0
#
#      parch      ticket   fare cabin embarked boat   body  \
# 591      2  C.A. 34651  27.75   NaN        S   10    NaN
# 518      1  C.A. 33112  36.75   NaN        S  NaN  101.0
# 682      2      364848   7.75   NaN        Q  NaN    NaN
#
#                   home.dest
# 591     Bournmouth, England
# 518  Cornwall / Hancock, MI
# 682     Ireland Chicago, IL

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">shape</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">  number of rows and columns in tuple format <br /></span></strong></p>
# </div>

# %%
a = titanic_data.shape

# %%
a
# Out:
# (1309, 14)

# %%
type(a)
# Out:
# tuple

# %%
a[0]
# Out:
# 1309

# %%
a[1]
# Out:
# 14

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">Columns</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">   name of each columns <br /></span></strong></p>
# </div>

# %%
titanic_data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">dtypes</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">    each column names and their type   <br /></span></strong></p>
# </div>

# %%
titanic_data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;">info()</span></strong>
# <p style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"> Whole Informtion<br /></span></strong></p>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em><span style="font-size: 12pt;"> number of whole data </span></em></span></strong></p>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em><span style="font-size: 12pt;">  Columnes with their names and types     </span></em></span></strong></p>
# <p dir="rtl" style="text-align: right;"><strong><span style="font-family: courier new, courier;"><em><span style="font-size: 12pt;">number of data for each column not-null</span></em></span></strong></p>
# </div>

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic_data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881138     0.498854     0.385027
# std       0.837836     0.486055    14.413493     1.041658     0.865560
# min       1.000000     0.000000     0.170000     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><span style="font-family: courier new, courier;"><span style="font-size: 18pt;"><strong>Select a row or column</strong></span><span style="font-size: 18pt;"><br /></span></span></div>

# %%
titanic_data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.00      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.92      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.00      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.00      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
#select the rows between 10 to 15
titanic_data['survived'][10:15]
# Out:
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# Name: survived, dtype: int64

# %%
#only one column
titanic_data.survived[10:15]
# Out:
# 10    0
# 11    1
# 12    1
# 13    1
# 14    1
# Name: survived, dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier;"><span style="font-size: 18pt;">  Select multiple coulmns based on their title </span><span style="font-size: 18pt;"><br /></span></span></strong></div>

# %%
titanic_data[['survived','age','fare']][10:15]
# Out:
#     survived   age     fare
# 10         0  47.0  227.525
# 11         1  18.0  227.525
# 12         1  24.0   69.300
# 13         1  26.0   78.850
# 14         1  80.0   30.000

# %%
titanic_data[['survived','age','fare']].head()
# Out:
#    survived    age      fare
# 0         1  29.00  211.3375
# 1         1   0.92  151.5500
# 2         0   2.00  151.5500
# 3         0  30.00  151.5500
# 4         0  25.00  151.5500

# %%
titanic_data[['survived','age','fare']][22:26]
# Out:
#     survived   age      fare
# 22         1  26.0   30.0000
# 23         1  42.0  227.5250
# 24         1  29.0  221.7792
# 25         0  25.0   26.0000

# %%
titanic_data[['survived','age','fare']][10:20:2]
# Out:
#     survived   age      fare
# 10         0  47.0  227.5250
# 12         1  24.0   69.3000
# 14         1  80.0   30.0000
# 16         0  24.0  247.5208
# 18         1  32.0   76.2917

# %% [markdown]
# <div class="alert alert-block alert-info" dir="ltr" style="text-align: center;"><strong><span style="font-family: courier new, courier; font-size: 18pt;"><em>value_counts</em>()</span></strong>
# </div>

# %%
titanic_data['pclass'].value_counts()
# Out:
# 3    709
# 1    323
# 2    277
# Name: pclass, dtype: int64

# %%
columns = titanic_data.columns
pd.crosstab(titanic_data['sex'],titanic_data['survived'])
# Out:
# survived    0    1
# sex
# female    127  339
# male      682  161

# %%
below_5_years = titanic_data[titanic_data['age'] <= 5]

# %%
below_5_years[0:3]
# Out:
#     pclass  survived                            name     sex   age  sibsp  \
# 1        1         1  Allison, Master. Hudson Trevor    male  0.92      1
# 2        1         0    Allison, Miss. Helen Loraine  female  2.00      1
# 94       1         1       Dodge, Master. Washington    male  4.00      0
#
#     parch  ticket      fare    cabin embarked boat  body  \
# 1       2  113781  151.5500  C22 C26        S   11   NaN
# 2       2  113781  151.5500  C22 C26        S  NaN   NaN
# 94      2   33638   81.8583      A34        S    5   NaN
#
#                           home.dest
# 1   Montreal, PQ / Chesterville, ON
# 2   Montreal, PQ / Chesterville, ON
# 94                San Francisco, CA

# %%
titanic_data[titanic_data.age <= 5][['survived', 'age']]
# Out:
#       survived   age
# 1            1  0.92
# 2            0  2.00
# 94           1  4.00
# 339          1  1.00
# 340          1  4.00
# 359          1  0.83
# 427          1  0.67
# 478          1  1.00
# 479          1  3.00
# 492          1  1.00
# 514          1  2.00
# 515          1  3.00
# 540          1  2.00
# 548          1  0.83
# 549          1  3.00
# 587          1  2.00
# 588          1  4.00
# 590          1  0.92
# 591          1  5.00
# 611          1  0.83
# 622          0  4.00
# 624          0  2.00
# 639          0  5.00
# 641          1  3.00
# 643          1  5.00
# 657          1  0.75
# 658          1  0.75
# 659          1  5.00
# 734          1  3.00
# 747          0  0.33
# 762          1  1.00
# 763          1  0.17
# 794          1  5.00
# 826          0  1.00
# 866          1  2.00
# 894          1  4.00
# 895          1  1.00
# 916          1  4.00
# 934          1  4.00
# 937          0  1.00
# 1048         1  1.00
# 1096         0  2.00
# ...

# %%
titanic_data[titanic_data['age'] <= 5][['survived']].value_counts(normalize=True)
# Out:
# survived
# 1           0.660714
# 0           0.339286
# dtype: float64

# %%
titanic_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
titanic_data[titanic_data['name'].str.contains('Rose', 'Jack')][['name','age']]
# Out:
#                                             name   age
# 242                Rosenbaum, Miss. Edith Louise  33.0
# 243  Rosenshine, Mr. George ("Mr George Thorne")  46.0
# 612                   Aks, Mrs. Sam (Leah Rosen)  18.0

# %%
titanic_data[titanic_data['home.dest'].str.contains('TR', na=False)][['home.dest']]
# Out:
# Empty DataFrame
# Columns: [home.dest]
# Index: []

# %%
titanic_data.embarked.unique()
# Out:
# array(['S', 'C', nan, 'Q'], dtype=object)

# %%
#titanic_data[titanic_data.survived == 1) & tita]

# %%
titanic_data[titanic_data.age.isnull()][['age', 'survived', 'sex', 'pclass']][0:5]
# Out:
#     age  survived     sex  pclass
# 15  NaN         0    male       1
# 37  NaN         1    male       1
# 40  NaN         0    male       1
# 46  NaN         0    male       1
# 59  NaN         1  female       1

# %%
titanic_data.groupby('pclass')['fare'].mean()
# Out:
# pclass
# 1    87.508992
# 2    21.179196
# 3    13.302889
# Name: fare, dtype: float64

# %%
#groupby titanic data by pclass and sexp
pclass_gender_age_mean_df = titanic_data.groupby(['pclass', 'sex'])['fare'].mean().reset_index()
pclass_gender_age_mean_df
# Out:
#    pclass     sex        fare
# 0       1  female  109.412385
# 1       1    male   69.888385
# 2       2  female   23.234827
# 3       2    male   19.904946
# 4       3  female   15.324250
# 5       3    male   12.415462

# %%
titanic_data.sort_values('age', ascending=False)
# Out:
#       pclass  survived                                               name  \
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 1235       3         0                                Svensson, Mr. Johan
# 135        1         0                          Goldschmidt, Mr. George B
# 9          1         0                            Artagaveytia, Mr. Ramon
# ...      ...       ...                                                ...
# 1293       3         0                  Williams, Mr. Howard Hugh "Harry"
# 1297       3         0                             Wiseman, Mr. Phillippe
# 1302       3         0                                  Yousif, Mr. Wazli
# 1303       3         0                              Yousseff, Mr. Gerious
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch      ticket     fare cabin embarked boat  \
# ...

# %%
titanic_data.iloc[3]
titanic_data.iloc[[3, 5 ,8]]
# Out:
#    pclass  survived                                           name     sex  \
# 3       1         0           Allison, Mr. Hudson Joshua Creighton    male
# 5       1         1                            Anderson, Mr. Harry    male
# 8       1         1  Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
#
#     age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 3  30.0      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 5  48.0      0      0   19952   26.5500      E12        S    3    NaN
# 8  53.0      2      0   11769   51.4792     C101        S    D    NaN
#
#                          home.dest
# 3  Montreal, PQ / Chesterville, ON
# 5                     New York, NY
# 8              Bayside, Queens, NY

# %%
titanic_data.iloc[9:13, 2:4]
# Out:
#                                                  name     sex
# 9                             Artagaveytia, Mr. Ramon    male
# 10                             Astor, Col. John Jacob    male
# 11  Astor, Mrs. John Jacob (Madeleine Talmadge Force)  female
# 12                      Aubart, Mme. Leontine Pauline  female

# %%
#titanic_data.loc[:, ['pclass, Miss Elisabeth Walton']]

# %%
titanic_data.query('survived > 60 and embarked == "S"' and 'age > 60')
# Out:
#       pclass  survived                                               name  \
# 6          1         1                  Andrews, Miss. Kornelia Theodosia
# 9          1         0                            Artagaveytia, Mr. Ramon
# 14         1         1               Barkworth, Mr. Algernon Henry Wilson
# 61         1         1  Cavendish, Mrs. Tyrell William (Julia Florence...
# 78         1         1  Compton, Mrs. Alexander Taylor (Mary Eliza Ing...
# 81         1         0                       Crosby, Capt. Edward Gifford
# 83         1         1  Crosby, Mrs. Edward Gifford (Catherine Elizabe...
# 115        1         0                                  Fortune, Mr. Mark
# 135        1         0                          Goldschmidt, Mr. George B
# 205        1         0                          Millet, Mr. Francis Davis
# 217        1         0                       Nicholson, Mr. Arthur Ernest
# 221        1         0                     Ostby, Mr. Engelhart Cornelius
# ...

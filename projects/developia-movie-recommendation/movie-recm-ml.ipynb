# %%
import pandas as pd
import numpy as np
from ast import literal_eval

# %%
df = pd.read_csv('/home/Machine Learning/projects/developia-movie-recommendation/dataset/movie_dataset.csv')

# %%
df.columns
# Out:
# Index(['_id', 'url', 'title', 'description', 'genres', 'runtime',
#        'runtime_str', 'release_date', 'langs', 'origins',
#        'production_companies', 'top_cast', 'director_creator', 'rate', 'type',
#        'img_url', 'keywords'],
#       dtype='object')

# %%
#insert user_id column to the df and fill it with random values between 1 and 300
df.insert(1, 'user_id', np.random.randint(1, 300, df.shape[0]))
df.columns
# Out:
# Index(['_id', 'user_id', 'url', 'title', 'description', 'genres', 'runtime',
#        'runtime_str', 'release_date', 'langs', 'origins',
#        'production_companies', 'top_cast', 'director_creator', 'rate', 'type',
#        'img_url', 'keywords'],
#       dtype='object')

# %%
df.head(3)
# Out:
#           _id  user_id                                    url  \
# 0   tt5315210      145   https://www.imdb.com/title/tt5315210
# 1  tt12593682       11  https://www.imdb.com/title/tt12593682
# 2  tt10648342      259  https://www.imdb.com/title/tt10648342
#
#                     title                                        description  \
# 0                     Lou  A storm rages. A young girl is kidnapped. Her ...
# 1            Bullet Train  Five assassins aboard a swiftly-moving bullet ...
# 2  Thor: Love and Thunder  Thor enlists the help of Valkyrie, Korg and ex...
#
#                               genres  runtime        runtime_str release_date  \
# 0       ['Action', 'Crime', 'Drama']    107.0  1 hour 47 minutes     23-09-22
# 1   ['Action', 'Comedy', 'Thriller']    127.0  2 hours 7 minutes     05-08-22
# 2  ['Action', 'Adventure', 'Comedy']    118.0  1 hour 58 minutes     08-07-22
#
#                                            langs  \
# 0                       ['English', 'Ukrainian']
# 1  ['English', 'Japanese', 'Spanish', 'Russian']
# 2                                    ['English']
#
#                           origins  \
# 0               ['United States']
# 1      ['United States', 'Japan']
# 2  ['Australia', 'United States']
#
#                                 production_companies  \
# 0                                      ['Bad Robot']
# 1     ['87North', 'CTB Inc.', 'Hill District Media']
# 2  ['Marvel Studios', 'Fox Studios Australia', 'W...
#
#                                             top_cast   director_creator  rate  \
# 0  [{'actor': 'Allison Janney', 'character': 'Lou...  ['Anna Foerster']   6.1
# 1  [{'actor': 'Brad Pitt', 'character': 'Ladybug'...   ['David Leitch']   7.4
# 2  [{'actor': 'Chris Hemsworth', 'character': 'Th...  ['Taika Waititi']   6.4
#
#     type                                            img_url  \
# 0  movie  https://m.media-amazon.com/images/M/MV5BYzdjMD...
# 1  movie  https://m.media-amazon.com/images/M/MV5BZTNmYj...
# 2  movie  https://m.media-amazon.com/images/M/MV5BYmQ3MW...
#
#                                             keywords
# 0                                                NaN
# 1  ['train', 'japan', 'assassin', 'revenge', 'mou...
# 2  ['superhero action', 'superhero', 'marvel comi...

# %%
#find the number of duplicate users
df['user_id'].value_counts()
# Out:
# 33     39
# 219    36
# 178    36
# 108    36
# 25     35
#        ..
# 78     16
# 286    16
# 90     15
# 156    15
# 50     13
# Name: user_id, Length: 299, dtype: int64

# %%
#create pivot table with column movie_id and index is user_id and fill NAs with 0
pt_df = df.pivot_table(index='user_id', columns='_id', values='rate').fillna(0)

# %%
#convert pivot table to CSR matrix
from scipy.sparse import csr_matrix # converted to csr matrix because of using making matrix calculations easily
csr_df = csr_matrix(pt_df.values)

# %%
#import svds
from locale import normalize
from scipy.sparse.linalg import svds

def normalize(X_pred):
    #normalize the prediction ratings
    X_pred = (X_pred - X_pred.min()) / (X_pred.max() - X_pred.min())
    return X_pred

def generate_prediction_df(csr_df, pt_df, n_factors):

    #matrix factorization from csr_df
    u, s, vt = svds(csr_df, k = n_factors)
    s_diag_matrix = np.diag(s)

    #calculate prediction ratings
    X_pred = np.dot(np.dot(u, s_diag_matrix), vt)
    X_pred = normalize(X_pred)

    #convert prediction ratings to dataframe
    pred_df = pd.DataFrame(X_pred, columns = pt_df.columns, index = list(pt_df.index)).transpose()
    
    return pred_df


def recommend_movies(pred_df, user_id, n_recs):
    user_preds = pred_df[user_id].sort_values(ascending=False).reset_index().rename(columns={user_id: 'similarity'})
    recommended_df = user_preds.sort_values(by='similarity', ascending=False).head(n_recs)

# %%
pred_df = generate_prediction_df(csr_df, pt_df, 10)

pred_df.head(3)
# Out:
#                     1             2             3             4    \
# _id
# tt0003740  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0004972  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0006864  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
#
#                     5             6             7             8    \
# _id
# tt0003740  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0004972  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0006864  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
#
#                     9             10   ...           290           291  \
# _id                                    ...
# tt0003740  8.999482e-14  8.999482e-14  ...  8.999482e-14  8.999482e-14
# tt0004972  8.999482e-14  8.999482e-14  ...  8.999482e-14  8.999482e-14
# tt0006864  8.999482e-14  8.999482e-14  ...  8.999482e-14  8.999482e-14
#
#                     292           293           294           295  \
# _id
# tt0003740  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0004972  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0006864  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
#
#                     296           297           298           299
# _id
# tt0003740  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0004972  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
# tt0006864  8.999482e-14  8.999482e-14  8.999482e-14  8.999482e-14
#
# [3 rows x 299 columns]

# %%
print(recommend_movies(pred_df, user_id=94, n_recs=10))
# Out:
# None

# %% [markdown]
# # Collaborative Filtering

# %%
df.head(3)
# Out:
#           _id  user_id                                    url  \
# 0   tt5315210      145   https://www.imdb.com/title/tt5315210
# 1  tt12593682       11  https://www.imdb.com/title/tt12593682
# 2  tt10648342      259  https://www.imdb.com/title/tt10648342
#
#                     title                                        description  \
# 0                     Lou  A storm rages. A young girl is kidnapped. Her ...
# 1            Bullet Train  Five assassins aboard a swiftly-moving bullet ...
# 2  Thor: Love and Thunder  Thor enlists the help of Valkyrie, Korg and ex...
#
#                               genres  runtime        runtime_str release_date  \
# 0       ['Action', 'Crime', 'Drama']    107.0  1 hour 47 minutes     23-09-22
# 1   ['Action', 'Comedy', 'Thriller']    127.0  2 hours 7 minutes     05-08-22
# 2  ['Action', 'Adventure', 'Comedy']    118.0  1 hour 58 minutes     08-07-22
#
#                                            langs  \
# 0                       ['English', 'Ukrainian']
# 1  ['English', 'Japanese', 'Spanish', 'Russian']
# 2                                    ['English']
#
#                           origins  \
# 0               ['United States']
# 1      ['United States', 'Japan']
# 2  ['Australia', 'United States']
#
#                                 production_companies  \
# 0                                      ['Bad Robot']
# 1     ['87North', 'CTB Inc.', 'Hill District Media']
# 2  ['Marvel Studios', 'Fox Studios Australia', 'W...
#
#                                             top_cast   director_creator  rate  \
# 0  [{'actor': 'Allison Janney', 'character': 'Lou...  ['Anna Foerster']   6.1
# 1  [{'actor': 'Brad Pitt', 'character': 'Ladybug'...   ['David Leitch']   7.4
# 2  [{'actor': 'Chris Hemsworth', 'character': 'Th...  ['Taika Waititi']   6.4
#
#     type                                            img_url  \
# 0  movie  https://m.media-amazon.com/images/M/MV5BYzdjMD...
# 1  movie  https://m.media-amazon.com/images/M/MV5BZTNmYj...
# 2  movie  https://m.media-amazon.com/images/M/MV5BYmQ3MW...
#
#                                             keywords
# 0                                                NaN
# 1  ['train', 'japan', 'assassin', 'revenge', 'mou...
# 2  ['superhero action', 'superhero', 'marvel comi...

# %%
from surprise import Reader

reader = Reader()

# %%
c_movies = df[['user_id', '_id', 'rate']]
# sort the dataset by user_id and copy
c_movies = c_movies.sort_values(by='user_id').copy()
c_movies.head(3)
# Out:
#       user_id         _id  rate
# 1174        1   tt0947798   8.0
# 7311        1  tt13446128   6.9
# 2335        1   tt0036775   8.3

# %%
#import Dataset and KFold
from surprise import Dataset
from surprise.model_selection import cross_validate, KFold

data = Dataset.load_from_df(c_movies[['_id', 'user_id', 'rate']], reader)
#split data into 5 folds for cross validation
kf = KFold(n_splits=5)
kf.split(data)


print(kf)
# Out:
# <surprise.model_selection.split.KFold object at 0x7f37d91a0670>

# %%
#import SVD
from surprise import SVD

svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    nan     nan     nan     nan     nan     nan     nan
# MAE (testset)     nan     nan     nan     nan     nan     nan     nan
# Fit time          0.53    0.51    0.63    0.50    0.45    0.52    0.06
# Test time         0.06    0.08    0.08    0.06    0.06    0.07    0.01
# {'test_rmse': array([nan, nan, nan, nan, nan]),
#  'test_mae': array([nan, nan, nan, nan, nan]),
#  'fit_time': (0.5284154415130615,
#   0.509331226348877,
#   0.6255173683166504,
#   0.5022017955780029,
#   0.45191311836242676),
#  'test_time': (0.06365442276000977,
#   0.08333444595336914,
#   0.08081531524658203,
#   0.05887889862060547,
#   0.05623960494995117)}

# %%
trainset = data.build_full_trainset()
svd.fit(trainset)

# %%
#get the greatest rate value for user 1
#df[df['user_id'] == 1]['rate'].max()
df[df['user_id'] == 1]
# Out:
#              _id  user_id                                    url  \
# 157    tt0416449        1   https://www.imdb.com/title/tt0416449
# 338    tt0117060        1   https://www.imdb.com/title/tt0117060
# 790    tt0089489        1   https://www.imdb.com/title/tt0089489
# 1174   tt0947798        1   https://www.imdb.com/title/tt0947798
# 1379  tt11847410        1  https://www.imdb.com/title/tt11847410
# 1680   tt9357050        1   https://www.imdb.com/title/tt9357050
# 1786   tt1282140        1   https://www.imdb.com/title/tt1282140
# 2335   tt0036775        1   https://www.imdb.com/title/tt0036775
# 5470  A military weapons engineer struggles to do hi...
# 6309  Confederate POWs escape a Union camp and make ...
# 6601  Forgiven is an inspirational story in the trad...
# 6724  Ernest Borgnine plays Rex Page, an old man who...
# 6870  Fact-based drama set during the 1967 Detroit r...
# 7079  When the communist government raises food pric...
# 7162  The rise and fall of a beauteous actress. She ...
# 7311  Destined couple, Bhop and Gaysorn, have their ...
#
#                                    genres  runtime         runtime_str  \
# 157                   ['Action', 'Drama']    117.0   1 hour 57 minutes
# 338   ['Action', 'Adventure', 'Thriller']    110.0   1 hour 50 minutes
# 790       ['Action', 'Horror', 'Mystery']    101.0   1 hour 41 minutes
# 1174                ['Drama', 'Thriller']    108.0   1 hour 48 minutes
# 1379                            ['Drama']     96.0   1 hour 36 minutes
# 1680                 ['Drama', 'Musical']    137.0  2 hours 17 minutes
# 1786       ['Comedy', 'Drama', 'Romance']     92.0   1 hour 32 minutes
# 2335      ['Crime', 'Drama', 'Film-Noir']    107.0   1 hour 47 minutes
# 2459         ['Comedy', 'Crime', 'Drama']     93.0   1 hour 33 minutes
# 2525       ['Crime', 'Drama', 'Thriller']     88.0   1 hour 28 minutes
# 2716     ['Adventure', 'Comedy', 'Music']     91.0   1 hour 31 minutes
# 2751    ['Adventure', 'Comedy', 'Family']    128.0   2 hours 8 minutes
# 2812    ['Adventure', 'Comedy', 'Sci-Fi']     96.0   1 hour 36 minutes
# 3243       ['Comedy', 'Horror', 'Sci-Fi']     88.0   1 hour 28 minutes
# 4364       ['Drama', 'Family', 'Fantasy']     93.0   1 hour 33 minutes
# 4751                  ['Drama', 'Horror']     92.0   1 hour 32 minutes
# 5156                              ['War']     91.0   1 hour 31 minutes
# 5165                     ['Drama', 'War']    128.0   2 hours 8 minutes
# 5180                     ['Drama', 'War']    103.0   1 hour 43 minutes
# 5255                     ['Drama', 'War']     97.0   1 hour 37 minutes
# 5470                    ['Comedy', 'War']     94.0   1 hour 34 minutes
# 6309                          ['Western']     88.0   1 hour 28 minutes
# 6601                          ['Western']     90.0   1 hour 30 minutes
# 6724       ['Comedy', 'Drama', 'Western']     99.0   1 hour 39 minutes
# 6870        ['Crime', 'Drama', 'History']    143.0  2 hours 23 minutes
# 7079                 ['Drama', 'History']    121.0    2 hours 1 minute
# 7162       ['Comedy', 'Drama', 'History']    120.0             2 hours
# 7311     ['Comedy', 'History', 'Romance']    166.0  2 hours 46 minutes
#
#      release_date                                         langs  \
# 157      16-03-07                                   ['English']
# 338      20-09-96                ['English', 'French', 'Czech']
# 790           NaN                                   ['English']
# 1174     25-02-11              ['English', 'French', 'Italian']
# 1379     27-01-22                                   ['English']
# 1680     24-09-21                                   ['English']
# 1786     17-09-21                                   ['English']
# 2335     06-09-44                                   ['English']
# 2459     24-02-17                                   ['English']
# 2525     02-09-16                        ['English', 'Spanish']
# 2716     01-09-21  ['English', 'German', 'Chaozhou', 'Spanish']
# 2751     24-05-19                         ['English', 'Arabic']
# 2812     24-06-87                         ['English', 'German']
# 3243     27-05-88                                   ['English']
# 4364          NaN                                   ['English']
# 4751     26-01-01        ['English', 'German', 'Luxembourgish']
# 5156     09-09-22                        ['Finnish', 'English']
# 5165          NaN                        ['English', 'Spanish']
# 5180          NaN     ['English', 'German', 'Spanish', 'Latin']
# 5255          NaN                                   ['English']
# 5470     20-07-84                        ['English', 'Spanish']
# 6309          NaN                                   ['English']
# 6601     22-03-11                                   ['English']
# 6724     27-04-12                                   ['English']
# 6870     04-08-17                                   ['English']
# 7079     01-10-21                                   ['Russian']
# 7162     18-09-98                           ['French', 'Latin']
# 7311     28-07-22                                      ['Thai']
#
#                                                 origins  \
# 157             ['United States', 'Canada', 'Bulgaria']
# 338                                   ['United States']
# 790                                  ['United Kingdom']
# 1174                                  ['United States']
# 1379                                  ['United States']
# 1680                ['United States', 'Japan', 'China']
# 1786                                  ['United States']
# 2335                                  ['United States']
# 2459                                  ['United States']
# 2525                                         ['France']
# 2716                                  ['United States']
# 2751                ['United States', 'United Kingdom']
# 2812                                  ['United States']
# 3243                                  ['United States']
# 4364                                         ['Canada']
# 4751  ['United Kingdom', 'Luxembourg', 'United States']
# 5156                                        ['Finland']
# 5165                        ['United States', 'Mexico']
# 5180                ['United Kingdom', 'United States']
# 5255                                  ['United States']
# 5470                                  ['United States']
# 6309                                  ['United States']
# 6601                                  ['United States']
# 6724                                  ['United States']
# 6870                                  ['United States']
# 7079                                         ['Russia']
# 7162        ['France', 'Italy', 'Spain', 'Switzerland']
# 7311                                       ['Thailand']
#
#                                    production_companies  \
# 157   ['Warner Bros.', 'Legendary Entertainment', 'V...
# 338   ['Paramount Pictures', 'Cruise/Wagner Producti...
# 790                 ['Easedram', 'London-Cannon Films']
# 1174  ['Searchlight Pictures', 'Cross Creek Pictures...
# 1379  ['SSS Entertainment', 'Good Pals', 'SSS Film C...
# 1680  ['Marc Platt Productions', 'Perfect World Pict...
# 1786      ['Screen Gems', 'Olive Bridge Entertainment']
# 2335                             ['Paramount Pictures']
# 2459                      ['Film Science', 'XYZ Films']
# 2525  ['Lionsgate', 'Why Not Productions', 'Wild Bun...
# 2716  ['Hammerstone Studios', 'Dugan Entertainment',...
# 2751  ['Walt Disney Pictures', 'Lin Pictures', 'Ride...
# 2812       ['Brooksfilms', 'Metro-Goldwyn-Mayer (MGM)']
# 3243  ['Sarlui / Diamant', 'Chiodo Brothers Producti...
# 4364  ['Buffalo Gal Pictures', 'Interstate 80 Entert...
# 4751  ['Saturn Films', 'Long Shot Pictures', 'BBC Fi...
# 5156                     ['Subzero Film Entertainment']
# 5165  ["Cinema '84", "Lion's Gate Films", 'Under Fir...
# 5180                              ['Sumar Productions']
# 5255                           ['Melville Productions']
# 5470    ['Cinema Group Ventures', 'Paramount Pictures']
# 6309  ['Columbia Pictures', 'Sage Western Pictures I...
# 6601                  ['Dirt Road Productions, Fresno']
# 6724                                      ['Filmatics']
# 6870  ['Annapurna Pictures', 'First Light Production...
# 7079       ['Production Center of Andrei Konchalovsky']
# 7162       ['Stéphan Films', 'France 3 Cinéma', 'AMLF']
# 7311                      ['GDH 559', 'Jorkwang Films']
#
#                                                top_cast  \
# 157   [{'actor': 'Gerard Butler', 'character': 'King...
# 338   [{'actor': 'Tom Cruise', 'character': 'Ethan H...
# 790   [{'actor': 'Steve Railsback', 'character': 'Ca...
# 1174  [{'actor': 'Natalie Portman', 'character': 'Ni...
# 1379  [{'actor': 'Jenna Ortega', 'character': 'Vada ...
# 1680  [{'actor': 'Ben Platt', 'character': 'Evan Han...
# 1786  [{'actor': 'Emma Stone', 'character': 'Olive',...
# 2335  [{'actor': 'Fred MacMurray', 'character': 'Wal...
# 2459  [{'actor': 'Melanie Lynskey', 'character': 'Ru...
# 2525  [{'actor': 'Mel Gibson', 'character': 'Link', ...
# 2716  [{'actor': 'Keanu Reeves', 'character': 'Ted',...
# 2751  [{'actor': 'Will Smith', 'character': 'Genie',...
# 2812  [{'actor': 'Mel Brooks', 'character': 'Preside...
# 3243  [{'actor': 'Grant Cramer', 'character': 'Mike ...
# 4364  [{'actor': 'Jordan Butterill', 'character': 'S...
# 4751  [{'actor': 'John Malkovich', 'character': 'Fri...
# 5156  [{'actor': 'Aksel Hennie', 'character': None, ...
# 5165  [{'actor': 'Nick Nolte', 'character': 'Russell...
# 5180  [{'actor': 'Clifton Webb', 'character': 'Lt. C...
# 5255  [{'actor': 'Gregory Peck', 'character': 'Lt. J...
# 5470  [{'actor': 'Dudley Moore', 'character': 'Wylie...
# 6309  [{'actor': 'Inger Stevens', 'character': 'Emil...
# 6601  [{'actor': 'Alan Autry', 'character': 'Jake Ki...
# 6724  [{'actor': 'Ernest Borgnine', 'character': 'Re...
# 6870  [{'actor': 'John Boyega', 'character': 'Dismuk...
# 7079  [{'actor': 'Yuliya Vysotskaya', 'character': "...
# 7162  [{'actor': 'Sophie Marceau', 'character': 'Mar...
# 7311  [{'actor': 'Tanawat Wattanaputi', 'character':...
#
#                       director_creator  rate   type  \
# 157                    ['Zack Snyder']   7.6  movie
# 338                 ['Brian De Palma']   7.1  movie
# 790                    ['Tobe Hooper']   6.1  movie
# 1174              ['Darren Aronofsky']   8.0  movie
# 1379                    ['Megan Park']   7.0  movie
# 1680               ['Stephen Chbosky']   6.1  movie
# 1786                    ['Will Gluck']   7.0  movie
# 2335                  ['Billy Wilder']   8.3  movie
# 2459                   ['Macon Blair']   6.9  movie
# 2525          ['Jean-François Richet']   6.4  movie
# 2716                  ['Dean Parisot']   5.9  movie
# 2751                   ['Guy Ritchie']   6.9  movie
# 2812                    ['Mel Brooks']   7.1  movie
# 3243                ['Stephen Chiodo']   6.1  movie
# 4364                  ['Dave Schultz']   5.9  movie
# 4751              ['E. Elias Merhige']   6.9  movie
# 5156              ['Jalmari Helander']   7.5  movie
# 5165            ['Roger Spottiswoode']   7.0  movie
# 5180                  ['Ronald Neame']   7.4  movie
# 5255               ['Lewis Milestone']   7.1  movie
# 5470                 ['Willard Huyck']   3.8  movie
# 0  movie  https://m.media-amazon.com/images/M/MV5BYzdjMD...      NaN

# %%
#get the most rated movies for user_id 94 after prediction
df[df['user_id'] == 94].sort_values(by='rate', ascending=False).head(10)
# Out:
#             _id  user_id                                   url  \
# 3809  tt0046250       94  https://www.imdb.com/title/tt0046250
# 2011  tt0315733       94  https://www.imdb.com/title/tt0315733
# 5778  tt0039941       94  https://www.imdb.com/title/tt0039941
# 462   tt1228705       94  https://www.imdb.com/title/tt1228705
# 3174  tt0104070       94  https://www.imdb.com/title/tt0104070
# 7054  tt7868082       94  https://www.imdb.com/title/tt7868082
# 3013  tt3874544       94  https://www.imdb.com/title/tt3874544
# 4835  tt0086508       94  https://www.imdb.com/title/tt0086508
# 4060  tt3850590       94  https://www.imdb.com/title/tt3850590
# 4038  tt0101775       94  https://www.imdb.com/title/tt0101775
#
#                            title  \
# 3809               Roman Holiday
# 2011                    21 Grams
# 5778             The Unsuspected
# 462                   Iron Man 2
# 3174           Death Becomes Her
# 7054  Charming the Hearts of Men
# 3013               The Boss Baby
# 4835              Uncommon Valor
# 4060                     Krampus
# 4038              Drop Dead Fred
#
#                                             description  \
# 3809  A bored and sheltered princess escapes her gua...
# 2011  A freak accident brings together a critically ...
# 5778  The secretary of an affably suave radio myster...
# 462   With the world now aware of his identity as Ir...
# 3174  When a fading actress learns of an immortality...
# 7054  A romantic drama set during the politically ch...
# 3013  A suit-wearing, briefcase-carrying baby pairs ...
# 4835  Ten years after his son went M.I.A. in Vietnam...
# 4060  A boy who has a bad Christmas accidentally sum...
# 4038  A young woman finds her already unstable life ...
#
#                                     genres  runtime        runtime_str  \
# 3809                 ['Comedy', 'Romance']    118.0  1 hour 58 minutes
# 2011        ['Crime', 'Drama', 'Thriller']    124.0  2 hours 4 minutes
# 5778     ['Drama', 'Film-Noir', 'Mystery']    103.0  1 hour 43 minutes
# 462      ['Action', 'Adventure', 'Sci-Fi']    124.0  2 hours 4 minutes
# 3174       ['Comedy', 'Fantasy', 'Horror']    104.0  1 hour 44 minutes
# 7054       ['Drama', 'History', 'Romance']    107.0  1 hour 47 minutes
# 3013  ['Animation', 'Adventure', 'Comedy']     97.0  1 hour 37 minutes
# 4835       ['Action', 'Drama', 'Thriller']    105.0  1 hour 45 minutes
# 4060        ['Comedy', 'Drama', 'Fantasy']     98.0  1 hour 38 minutes
# 4038        ['Comedy', 'Drama', 'Fantasy']    103.0  1 hour 43 minutes
#
#      release_date                             langs  \
# 3809     02-12-54  ['English', 'Italian', 'German']
# 2011     21-05-04                       ['English']
# 5778     03-11-49                       ['English']
# 462      07-05-10  ['English', 'French', 'Russian']
# 3174     25-12-92                       ['English']
# 7054     13-08-21                       ['English']
# 3013     31-03-17            ['English', 'Spanish']
# 4835     16-12-83                       ['English']
# 4060     04-12-15             ['English', 'German']
# 4038     19-03-93                       ['English']
#
#                                   origins  \
# 3809                    ['United States']
# 2011                    ['United States']
# 5778                    ['United States']
# 462                     ['United States']
# 3174                    ['United States']
# 7054                    ['United States']
# 3013                    ['United States']
# 4835                    ['United States']
# 4060                    ['United States']
# 4038  ['United States', 'United Kingdom']
#
#                                    production_companies  \
# 3809                             ['Paramount Pictures']
# 2011  ['This Is That Productions', 'Y Productions', ...
# 5778     ['Michael Curtiz Productions', 'Warner Bros.']
# 462   ['Paramount Pictures', 'Marvel Entertainment',...
# 3174                             ['Universal Pictures']
# 7054                         ['High Hopes Productions']
# 3013                           ['DreamWorks Animation']
# 4835         ['Paramount Pictures', 'Milius-Feitshans']
# 4060  ['Legendary Entertainment', 'Universal Picture...
# 4038  ['PolyGram Filmed Entertainment', 'Working Tit...
#
#                                                top_cast  \
# 3809  [{'actor': 'Gregory Peck', 'character': 'Joe B...
# 2011  [{'actor': 'Sean Penn', 'character': 'Paul Riv...
# 5778  [{'actor': 'Claude Rains', 'character': 'Victo...
# 462   [{'actor': 'Robert Downey Jr.', 'character': '...
# 3174  [{'actor': 'Meryl Streep', 'character': 'Madel...
# 7054  [{'actor': 'Anna Friel', 'character': 'Grace G...
# 3013  [{'actor': 'Alec Baldwin', 'character': 'Boss ...
# 4835  [{'actor': 'Gene Hackman', 'character': 'Col. ...
# 4060  [{'actor': 'Adam Scott', 'character': 'Tom', '...
# 4038  [{'actor': 'Phoebe Cates', 'character': 'Eliza...
#
#                director_creator  rate   type  \
# 3809          ['William Wyler']   8.0  movie
# 2011  ['Alejandro G. Iñárritu']   7.6  movie
# 5778         ['Michael Curtiz']   7.2  movie
# 462             ['Jon Favreau']   6.9  movie
# 3174        ['Robert Zemeckis']   6.6  movie
# 7054            ['S.E. DeRose']   6.4  movie
# 3013            ['Tom McGrath']   6.3  movie
# 4835           ['Ted Kotcheff']   6.3  movie
# 4060      ['Michael Dougherty']   6.2  movie
# 4038            ['Ate de Jong']   5.9  movie
#
#                                                 img_url  \
# 3809  https://m.media-amazon.com/images/M/MV5BMTE2MD...
# 2011  https://m.media-amazon.com/images/M/MV5BMjA4Mj...
# 5778  https://m.media-amazon.com/images/M/MV5BMDY0MT...
# 462   https://m.media-amazon.com/images/M/MV5BMTM0MD...
# 3174  https://m.media-amazon.com/images/M/MV5BNzM2Yj...
# 7054  https://m.media-amazon.com/images/M/MV5BNmI2NT...
# 3013  https://m.media-amazon.com/images/M/MV5BYTkxZm...
# 4835  https://m.media-amazon.com/images/M/MV5BNzE4Zj...
# 4060  https://m.media-amazon.com/images/M/MV5BMjk0Mj...
# 4038  https://m.media-amazon.com/images/M/MV5BMDNkZW...
#
#                                                keywords
# 3809  ['doctor', 'taxi', 'italy', 'american in italy...
# 2011  ['sex in bed', 'heart donor', 'unfaithfulness'...
# 5778                                                NaN
# 462   ['superhero', 'billionaire', 'power suit', 'ba...
# 3174  ['egocentric woman', 'frenemy', 'betrayal', 'e...
# 7054                                                NaN
# 3013  ['baby', 'brother brother relationship', 'talk...
# 4835  ['post traumatic stress disorder', 'vietnam', ...
# 4060  ['christmas', 'folklore', 'christmas horror', ...
# 4038  ['imaginary friend', 'emotional manipulation',...

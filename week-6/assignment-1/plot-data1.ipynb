# %% [markdown]
# # Part F

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/home/Machine Learning/week-6/assignment-1/dataset/dataset1_train.csv')
df.head(3)
# Out:
#         x_1         x_2    y
# 0  2.911809   60.359613  0.0
# 1  3.774746  344.149284  0.0
# 2  2.615488  178.222087  0.0

# %%
df.columns
# Out:
# Index(['x_1', 'x_2', 'y'], dtype='object')

# %% [markdown]
# for provided Dataset 1, Plot the training data using a horizontal axis of 𝑥1
# and a vertical axis of 𝑥2. For visualizing the two classes, try to use a different symbol for
# samples 𝑥(𝑖) with 𝑦(𝑖) = 0 than for those with 𝑦(𝑖) = 1. On the same figure, plot the decision
# boundary which found by logistic regression in part (b).
# Repeat the same procedure to make an identical plot with the decision boundary which found
# by GDA in part (e).

# %%
#print df where y is 1
print(df[df['y'] == 1], df[df['y'] == 0])
# Out:
#           x_1        x_2    y
# 400  3.723523  10.587718  1.0
# 401  2.205164   7.190778  1.0
# 402  4.244613  33.274952  1.0
# 403  5.395384  83.759385  1.0
# 404  5.032398  35.740489  1.0
# ..        ...        ...  ...
# 795  3.724697  23.219963  1.0
# 796  3.139055   5.970538  1.0
# 797  2.969095  20.249978  1.0
# 798  3.957531  27.261970  1.0
# 799  4.025334  12.233165  1.0
#
# [400 rows x 3 columns]           x_1         x_2    y
# 0    2.911809   60.359613  0.0
# 1    3.774746  344.149284  0.0
# 2    2.615488  178.222087  0.0
# 3    2.013694   15.259472  0.0
# 4    2.757625   66.194174  0.0
# ..        ...         ...  ...
# 395  2.826022  110.699154  0.0
# 396  2.314879   55.232261  0.0
# 397  3.937673  118.248821  0.0
# 398  3.944834  105.106484  0.0
# 399  4.309058  185.587247  0.0
#
# [400 rows x 3 columns]

# %%
# make loop with the size of df
for i in range(len(df)):
    # if y is 1
    if df['y'][i] == 1:
        # plot x1 and x2 with red color
        plt.scatter(df['x_1'][i], df['x_2'][i], c='r', marker='o')
    # if y is 0
    else:
        # plot x1 and x2 with blue color
        plt.scatter(df['x_1'][i], df['x_2'][i], c='b', marker='x')

# I additionally used different color to show 𝑥(𝑖) with 𝑦(𝑖) = 0 than for those with 𝑦(𝑖) = 1. Because using same color and symbol for both of them is not clear to see.

# %% [markdown]
# # Part G

# %%
df = pd.read_csv('/home/Machine Learning/week-6/assignment-1/dataset/dataset2_train.csv')
df.head(3)
# Out:
#         x_1       x_2    y
# 0  3.759481  7.507940  0.0
# 1  3.422057  4.991203  0.0
# 2  2.778818  4.112071  0.0

# %%
# make loop with the size of df
for i in range(len(df)):
    # if y is 1
    if df['y'][i] == 1:
        # plot x1 and x2 with red color
        plt.scatter(df['x_1'][i], df['x_2'][i], c='r',marker='o')
    # if y is 0
    else:
        # plot x1 and x2 with blue color
        plt.scatter(df['x_1'][i], df['x_2'][i], c='b', marker='x')

# I additionally used different color to show 𝑥(𝑖) with 𝑦(𝑖) = 0 than for those with 𝑦(𝑖) = 1. Because using same color and symbol for both of them is not clear to see.
